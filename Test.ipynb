# %% [markdown]
# ### Title
# 1. 1
# 1. 2

# %%
import numpy as np
import seaborn as sns

# %%
x = np.array([1,2,4,5,6,7,8,9,7,4,4,4,1])
sns.distplot(x)

# %% [markdown]
# # Header 1. You can find more rules for Markdown formatting in this Markdown Cheatsheet: https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet
